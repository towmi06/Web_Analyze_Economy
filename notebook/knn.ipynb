# %% [markdown]
# Importng the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
file_path = 'H:\WEB_ECO\Web_Analyze_Economy\Data\Total.csv'
df = pd.read_csv(file_path, encoding = 'ISO-8859-1')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\admin\AppData\Local\Temp\ipykernel_10448\3147051908.py:1: SyntaxWarning: invalid escape sequence '\W'
#   file_path = 'H:\WEB_ECO\Web_Analyze_Economy\Data\Total.csv'
#    STT       Country Continents  Rate of users Internet (%)  \
# 0    1       Algeria   Africa                          20.0
# 1    2        Angola   Africa                          15.0
# 2    3         Benin   Africa                          13.0
# 3    4      Botswana   Africa                          21.0
# 4    5  Burkina Faso   Africa                           4.5
#
#    Mobile device usage (%)  Revenue of ecommerce platforms (billion USD)  \
# 0                     97.0                                          0.50
# 1                     44.3                                          0.25
# 2                     55.0                                          0.12
# ...

# %%
df2 = df.drop('STT',axis='columns')
df2.head()
# Out:
#         Country Continents  Rate of users Internet (%)  \
# 0       Algeria   Africa                          20.0
# 1        Angola   Africa                          15.0
# 2         Benin   Africa                          13.0
# 3      Botswana   Africa                          21.0
# 4  Burkina Faso   Africa                           4.5
#
#    Mobile device usage (%)  Revenue of ecommerce platforms (billion USD)  \
# 0                     97.0                                          0.50
# 1                     44.3                                          0.25
# 2                     55.0                                          0.12
# 3                     77.0                                          0.20
# 4                     65.5                                          0.10
#
#    Revenue of IT industry (billion USD)  \
# 0                                  0.80
# 1                                  0.37
# 2                                  0.07
# ...

# %% [markdown]
# Cleaning data

# %%
#Kiểm tra và thay thế các giá trị không hợp lệ
import pandas as pd
import numpy as np
df2.replace(' - ', np.nan, inplace=True) 
df2.dropna(inplace=True)

# %%
print(df2.columns)
# Out:
# Index(['Country', 'Continents', 'Rate of users Internet (%)',
#        'Mobile device usage (%)',
#        'Revenue of ecommerce platforms (billion USD)',
#        'Revenue of IT industry (billion USD)',
#        'Funding in digital infrastructure (billion USD)',
#        'Foreign investment capital (billion USD)',
#        'CREDIT and BANKING digital transformation ratio(%)',
#        'Number of Enterprises Applying Digital Transformation (bussiness)',
#        'Economic Growth Rate of Education (% GDP)',
#        'Number of technology start up businesses', 'Year'],
#       dtype='object')

# %%
# Chuyển đổi các cột cần thiết sang kiểu số
cols_to_convert = ['Rate of users Internet (%)', 'Mobile device usage (%)', 'Revenue of ecommerce platforms (billion USD)', 
                   'Revenue of IT industry (billion USD)', 'Funding in digital infrastructure (billion USD)', 
                   'Foreign investment capital (billion USD)', 'CREDIT and BANKING digital transformation ratio(%)', 
                   'Number of Enterprises Applying Digital Transformation (bussiness)', 
                   'Economic Growth Rate of Education (% GDP)', 'Number of technology start up businesses']

for col in cols_to_convert:
    df2[col] = pd.to_numeric(df2[col], errors='coerce')

df2.dropna(inplace=True)  # Loại bỏ các hàng chứa NaN sau khi chuyển đổi

# %%
X = df2[cols_to_convert].values
y = df2['Year'].values

# %% [markdown]
# Splitting the dataset into the Training set and Test set

# %%
#check null 
null_values = df2.isnull().sum()

# Value = 0
zero_values = (df2 == 0).sum()

print("The numbers is null:\n", null_values)
print("\n Equal 0 :\n", zero_values)
# Out:
# The numbers is null:
#  Country                                                              0
# Continents                                                           0
# Rate of users Internet (%)                                           0
# Mobile device usage (%)                                              0
# Revenue of ecommerce platforms (billion USD)                         0
# Revenue of IT industry (billion USD)                                 0
# Funding in digital infrastructure (billion USD)                      0
# Foreign investment capital (billion USD)                             0
# CREDIT and BANKING digital transformation ratio(%)                   0
# Number of Enterprises Applying Digital Transformation (bussiness)    0
# Economic Growth Rate of Education (% GDP)                            0
# Number of technology start up businesses                             0
# Year                                                                 0
# dtype: int64
#
# ...
