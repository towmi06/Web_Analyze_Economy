# %% [markdown]
# <a href="https://colab.research.google.com/github/towmi06/Web_Analyze_Economy/blob/Algorithms/ttcs1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
file_path = '/content/Total (1).csv'
df1 = pd.read_csv(file_path, encoding='ISO-8859-1')

df1.head()
# Out:
#    STT       Country Continents  Rate of users\nInternet (%)  \
# 0  1.0       Algeria   Africa                           20.0
# 1  2.0        Angola   Africa                           15.0
# 2  3.0         Benin   Africa                           13.0
# 3  4.0      Botswana   Africa                           21.0
# 4  5.0  Burkina Faso   Africa                            4.5
#
#    Mobile device usage (%)  Revenue of e-commerce platforms (billion USD)  \
# 0                     97.0                                           0.50
# 1                     44.3                                           0.25
# 2                     55.0                                           0.12
# 3                     77.0                                           0.20
# 4                     65.5                                           0.10
#
#    Revenue of IT industry (billion USD)  \
# 0                                  0.80
# 1                                  0.37
# 2                                  0.07
# 3                                  0.20
# 4                                  0.10
#
#    Funding in digital infrastructure (billion USD)  \
# 0                                             0.10
# 1                                             0.10
# 2                                             0.10
# 3                                             0.07
# 4                                             0.06
#
#    Foreign investment capital (million USD)  \
# 0                                      1.50
# 1                                      3.66
# 2                                      0.41
# 3                                      0.52
# 4                                      0.36
#
#    CREDIT and BANKING digital transformation ratio(%)  \
# 0                                                0.0
# 1                                               12.8
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Number of Enterprises Applying Digital Transformation (bussiness)   \
# 0                                            12,000
# 1                                            15,000
# 2                                            10,000
# 3                                            18,000
# 4                                             8,000
#
#    Economic Growth Rate of Education (% GDP)  \
# 0                                        4.1
# 1                                        3.5
# 2                                        3.5
# 3                                        6.0
# 4                                        4.0
#
#    Number of technology start up businesses     Year  Unnamed: 14  \
# 0                                       800   2014.0          NaN
# 1                                       170   2014.0          NaN
# 2                                        80   2014.0          NaN
# 3                                       280   2014.0          NaN
# 4                                        55   2014.0          NaN
#
#    Unnamed: 15  Unnamed: 16
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
# view dimensions of dataset

df1.shape
# Out:
# (2050, 17)

# %%
#Sao chép dữ liệu
df = df1

# %%
df.head()
# Out:
#    STT       Country Continents  Rate of users\nInternet (%)  \
# 0  1.0       Algeria   Africa                           20.0
# 1  2.0        Angola   Africa                           15.0
# 2  3.0         Benin   Africa                           13.0
# 3  4.0      Botswana   Africa                           21.0
# 4  5.0  Burkina Faso   Africa                            4.5
#
#    Mobile device usage (%)  Revenue of e-commerce platforms (billion USD)  \
# 0                     97.0                                           0.50
# 1                     44.3                                           0.25
# 2                     55.0                                           0.12
# 3                     77.0                                           0.20
# 4                     65.5                                           0.10
#
#    Revenue of IT industry (billion USD)  \
# 0                                  0.80
# 1                                  0.37
# 2                                  0.07
# 3                                  0.20
# 4                                  0.10
#
#    Funding in digital infrastructure (billion USD)  \
# 0                                             0.10
# 1                                             0.10
# 2                                             0.10
# 3                                             0.07
# 4                                             0.06
#
#    Foreign investment capital (million USD)  \
# 0                                      1.50
# 1                                      3.66
# 2                                      0.41
# 3                                      0.52
# 4                                      0.36
#
#    CREDIT and BANKING digital transformation ratio(%)  \
# 0                                                0.0
# 1                                               12.8
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Number of Enterprises Applying Digital Transformation (bussiness)   \
# 0                                            12,000
# 1                                            15,000
# 2                                            10,000
# 3                                            18,000
# 4                                             8,000
#
#    Economic Growth Rate of Education (% GDP)  \
# 0                                        4.1
# 1                                        3.5
# 2                                        3.5
# 3                                        6.0
# 4                                        4.0
#
#    Number of technology start up businesses     Year  Unnamed: 14  \
# 0                                       800   2014.0          NaN
# 1                                       170   2014.0          NaN
# 2                                        80   2014.0          NaN
# 3                                       280   2014.0          NaN
# 4                                        55   2014.0          NaN
#
#    Unnamed: 15  Unnamed: 16
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
#Xóa các cột sau năm
df = df.loc[:, :'Year']

# %%
#Loại bỏ các hàng ở dưới
df = df[:1520].dropna()
df.tail()
# Out:
#          STT      Country      Continents  Rate of users\nInternet (%)  \
# 1513  1514.0     Malaysia  Southeast Asia                         93.0
# 1514  1515.0    Indonesia  Southeast Asia                         80.0
# 1515  1516.0  Philippines  Southeast Asia                         80.0
# 1516  1517.0       Brunei  Southeast Asia                         97.5
# 1517  1518.0  Timor-Leste  Southeast Asia                         40.0
#
#       Mobile device usage (%)  Revenue of e-commerce platforms (billion USD)  \
# 1513                     95.0                                        560.000
# 1514                     92.0                                        580.000
# 1515                     96.0                                         10.000
# 1516                     94.0                                          0.150
# 1517                     82.0                                          0.012
#
#       Revenue of IT industry (billion USD)  \
# 1513                                 5.120
# 1514                                 5.590
# 1515                                 2.260
# 1516                                 0.073
# 1517                                 0.040
#
#       Funding in digital infrastructure (billion USD)  \
# 1513                                             0.65
# 1514                                             0.60
# 1515                                             0.55
# 1516                                             0.13
# 1517                                             0.05
#
#       Foreign investment capital (million USD)  \
# 1513                                       0.0
# 1514                                       3.9
# 1515                                       0.4
# 1516                                       0.4
# 1517                                       0.0
#
#       CREDIT and BANKING digital transformation ratio(%)  \
# 1513                                               60.0
# 1514                                               60.0
# 1515                                               50.0
# 1516                                               50.0
# 1517                                               50.0
#
#       Number of Enterprises Applying Digital Transformation (bussiness)   \
# 1513                                            75,000
# 1514                                           130,000
# 1515                                            65,000
# 1516                                            30,000
# 1517                                             3,500
#
#       Economic Growth Rate of Education (% GDP)  \
# 1513                                        5.6
# 1514                                        5.0
# 1515                                        4.7
# 1516                                        3.1
# 1517                                        5.6
#
#       Number of technology start up businesses     Year
# 1513                                     5,500   2024.0
# 1514                                     4,800   2024.0
# 1515                                     5,000   2024.0
# 1516                                       250   2024.0
# 1517                                       110   2024.0

# %%
df.shape
# Out:
# (1518, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1518 entries, 0 to 1517
# Data columns (total 14 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   STT                                                                  1518 non-null   float64
#  1   Country                                                              1518 non-null   object
#  2   Continents                                                           1518 non-null   object
#  3   Rate of users
# Internet (%)                                           1518 non-null   float64
#  4   Mobile device usage (%)                                              1518 non-null   float64
#  5   Revenue of e-commerce platforms (billion USD)                        1518 non-null   float64
#  6   Revenue of IT industry (billion USD)                                 1518 non-null   float64
#  7   Funding in digital infrastructure (billion USD)                      1518 non-null   float64
#  8   Foreign investment capital (million USD)                             1518 non-null   float64
#  9   CREDIT and BANKING digital transformation ratio(%)                   1518 non-null   float64
#  10   Number of Enterprises Applying Digital Transformation (bussiness)   1518 non-null   object
#  11  Economic Growth Rate of Education (% GDP)                            1518 non-null   float64
#  12   Number of technology start up businesses                            1518 non-null   object
#  13  Year                                                                 1518 non-null   float64
# dtypes: float64(10), object(4)
# memory usage: 177.9+ KB

# %%
df['Country'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Burundi', 'Cabo Verde (Cape Verde)', 'Cameroon',
#        'Central African Republic', 'Chad', 'Comoros',
#        'Congo, Democratic Republic of the (DR Congo)',
#        'Congo, Republic of the (Republic of the Congo)', 'Djibouti',
#        'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini (Swaziland)',
#        'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau',
#        "Ivory Coast (Côte d'Ivoire)", 'Kenya', 'Lesotho', 'Liberia',
#        'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania',
#        'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe', 'Canada',
#        'The United States', 'Mexico', 'Belize', 'Costa Rica',
#        'El Salvador', 'Guatemala', 'Honduras', 'Nicaragua', 'Panama',
#        'Antigua and Barbuda', 'Bahamas', 'Barbados', 'Cuba', 'Dominica',
#        'Dominican Republic', 'Grenada', 'Haiti', 'Jamaica',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and Grenadines', 'Trinidad and Tobago', 'Argentina',
#        'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana',
#        'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela', 'China',
#        'Japan', 'South Korea', 'India', 'Qatar', 'Saudi Arabia', 'Iran',
#        'Iraq', 'Nepal', 'Syria', 'Jordan', 'Israel', 'Palestine',
#        'Türkiye', 'Sri Lanka', 'Uzbekistan', 'Bahrain', 'Oman', 'The UK',
#        'France', 'Spain', 'Albania', 'Austria', 'Belarus', 'Belgium',
#        'Bulgaria', 'Croatia', 'Czech Republic', 'Denmark', 'Estonia',
#        'Germany', 'Greece', 'Hungary', 'Italy', 'Luxembourg',
#        'Netherlands', 'Bac Macedonia', 'Russia', 'Singapore', 'VietNam',
#        'Laos', 'Thailand', 'Cambodia', 'Myanmar', 'Malaysia', 'Indonesia',
#        'Philippines', 'Brunei', 'Timor-Leste'], dtype=object)

# %%
# drop stt
df = df.drop(columns=['STT'])

# %%
df.head()
# Out:
#         Country Continents  Rate of users\nInternet (%)  \
# 0       Algeria   Africa                           20.0
# 1        Angola   Africa                           15.0
# 2         Benin   Africa                           13.0
# 3      Botswana   Africa                           21.0
# 4  Burkina Faso   Africa                            4.5
#
#    Mobile device usage (%)  Revenue of e-commerce platforms (billion USD)  \
# 0                     97.0                                           0.50
# 1                     44.3                                           0.25
# 2                     55.0                                           0.12
# 3                     77.0                                           0.20
# 4                     65.5                                           0.10
#
#    Revenue of IT industry (billion USD)  \
# 0                                  0.80
# 1                                  0.37
# 2                                  0.07
# 3                                  0.20
# 4                                  0.10
#
#    Funding in digital infrastructure (billion USD)  \
# 0                                             0.10
# 1                                             0.10
# 2                                             0.10
# 3                                             0.07
# 4                                             0.06
#
#    Foreign investment capital (million USD)  \
# 0                                      1.50
# 1                                      3.66
# 2                                      0.41
# 3                                      0.52
# 4                                      0.36
#
#    CREDIT and BANKING digital transformation ratio(%)  \
# 0                                                0.0
# 1                                               12.8
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Number of Enterprises Applying Digital Transformation (bussiness)   \
# 0                                            12,000
# 1                                            15,000
# 2                                            10,000
# 3                                            18,000
# 4                                             8,000
#
#    Economic Growth Rate of Education (% GDP)  \
# 0                                        4.1
# 1                                        3.5
# 2                                        3.5
# 3                                        6.0
# 4                                        4.0
#
#    Number of technology start up businesses     Year
# 0                                       800   2014.0
# 1                                       170   2014.0
# 2                                        80   2014.0
# 3                                       280   2014.0
# 4                                        55   2014.0

# %%
# Kiểm tra các giá trị bị thiếu
print(df.isnull().sum())

# Xử lý giá trị thiếu
df.fillna(df.mean(), inplace=True)
# Out:
# Country                                                                0
# Continents                                                             0
# Rate of users\nInternet (%)                                            0
# Mobile device usage (%)                                                0
# Revenue of e-commerce platforms (billion USD)                          0
# Revenue of IT industry (billion USD)                                   0
# Funding in digital infrastructure (billion USD)                        0
# Foreign investment capital (million USD)                               0
# CREDIT and BANKING digital transformation ratio(%)                     0
#  Number of Enterprises Applying Digital Transformation (bussiness)     0
# Economic Growth Rate of Education (% GDP)                              0
#  Number of technology start up businesses                              0
# Year                                                                   0
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-749d0f93d76e> in <cell line: 5>()
#       3
#       4 # Xử lý giá trị thiếu
# ----> 5 df.fillna(df.mean(), inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11333         **kwargs,
#   11334     ):
# > 11335         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336         if isinstance(result, Series):
#   11337             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11990         **kwargs,
#   11991     ) -> Series | float:
# > 11992         return self._stat_function(
#   11993             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11947         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11948
# > 11949         return self._reduce(
#   11950             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11951         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11202         # After possibly _get_data and transposing, we are now in the
#   11203         #  simple case where we can use BlockManager.reduce
# > 11204         res = df._mgr.reduce(blk_func)
#   11205         out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11206         if out_dtype is not None and out.dtype != "boolean":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in reduce(self, func)
#    1457         res_blocks: list[Block] = []
#    1458         for blk in self.blocks:
# -> 1459             nbs = blk.reduce(func)
#    1460             res_blocks.extend(nbs)
#    1461
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in reduce(self, func)
#     375         assert self.ndim == 2
#     376
# --> 377         result = func(self.values)
#     378
#     379         if self.values.ndim == 1:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in blk_func(values, axis)
#   11134                     return np.array([result])
#   11135             else:
# > 11136                 return op(values, axis=axis, skipna=skipna, **kwds)
#   11137
#   11138         def _get_data() -> DataFrame:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     145                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#     149             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     402             mask = isna(values)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#     406         if datetimelike:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     718     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#     722     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1676             if inferred in ["string", "mixed"]:
#    1677                 # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1678                 raise TypeError(f"Could not convert {x} to numeric")
#    1679             try:
#    1680                 x = x.astype(np.complex128)
#
# TypeError: Could not convert ["AlgeriaAngolaBeninBotswanaBurkina FasoBurundiCabo Verde (Cape Verde)CameroonCentral African RepublicChadComorosCongo, Democratic Republic of the (DR Congo)Congo, Republic of the (Republic of the Congo)DjiboutiEgyptEquatorial GuineaEritreaEswatini (Swaziland)EthiopiaGabonGambiaGhanaGuineaGuinea-BissauIvory Coast (Côte d'Ivoire)KenyaLesothoLiberiaLibyaMadagascarMalawiMaliMauritaniaMauritiusMoroccoMozambiqueNamibiaNigerNigeriaRwandaSao Tome and PrincipeSenegalSeychellesSierra LeoneSomaliaSouth AfricaSouth SudanSudanTanzaniaTogoTunisiaUgandaZambiaZimbabweCanadaThe United StatesMexicoBelizeCosta RicaEl SalvadorGuatemalaHondurasNicaraguaPanamaAntigua and BarbudaBahamasBarbadosCubaDominicaDominican RepublicGrenadaHaitiJamaicaSaint Kitts and NevisSaint LuciaSaint Vincent and GrenadinesTrinidad and TobagoArgentinaBoliviaBrazilChileColombiaEcuadorGuyanaParaguayPeruSurinameUruguayVenezuelaChinaJapanSouth KoreaIndiaQatarSaudi ArabiaIranIraqNepalSyriaJordanIsraelPalestineTürkiyeSri LankaUzbekistanBahrainOmanThe UKFranceSpainAlbaniaAustriaBelarusBelgiumBulgariaCroatiaCzech RepublicDenmarkEstoniaGermanyGreeceHungaryItalyLuxembourgNetherlandsBac MacedoniaRussiaSingaporeVietNamLaosThailandCambodiaMyanmarMalaysiaIndonesiaPhilippinesBruneiTimor-LesteAlgeriaAngolaBeninBotswanaBurkina FasoBurundiCabo Verde (Cape Verde)CameroonCentral African RepublicChadComorosCongo, Democratic Republic of the (DR Congo)Congo, Republic of the (Republic of the Congo)Dji...
#  'Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  AmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAmericaAsia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Asia  Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Europe Southeast AsiaSoutheast AsiaSoutheast AsiaSoutheast AsiaSoutheast AsiaSoutheast AsiaSoutheast AsiaSoutheast AsiaSoutheast AsiaSoutheast AsiaSoutheast AsiaAfrica  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  Africa  ...
#  ' 12,000  15,000  10,000  18,000  8,000  4,000  8,000  18,000  4,000  8,000  3,000  40,000  8,000  4,000  70,000  3,000  4,000  8,000  40,000  10,000  3,000  50,000  7,000  3,000  40,000  40,000  4,000  4,000  40,000  20,000  10,000  8,000  4,000  20,000  70,000  20,000  10,000  8,000  200,000  25,000  3,000  40,000  6,000  5,000  5,000  40,000  4,000  8,000  50,000  4,000  40,000  30,000  15,000  20,000  300,000  300,000  50,000  2,000  25,000  10,000  10,000  -    -    50,000  3,000  10,000  20,000  4,000  2,000  25,000  -    6,000  -    1,800  2,500  2,000  60,000  60,000  15,000  80,000  80,000  80,000  25,000  -    12,000  12,000  2,500  60,000  40,000  55,000  28,000  18,000  27,000  600  2,700  1,300  600  350  400  1,000  3,300  400  5,500  400  500  400  350  40,000  25,000  15,000  2,500  22,000  3,000  18,000  3,000  2,500  5,000  13,000  1,500  45,000  3,500  3,000  20,000  1,200  18,000  700  2,000  2,700  750  500  1,000  1,000  1,000  5,000  5,000  3,000  1,000  100  15,000  20,000  12,000  22,000  10,000  5,000  10,000  22,000  5,000  10,000  4,000  50,000  10,000  5,000  80,000  4,000  5,000  10,000  50,000  12,000  4,000  60,000  8,000  4,000  50,000  50,000  5,000  5,000  50,000  25,000  12,000  10,000  5,000  25,000  80,000  25,000  12,000  10,000  250,000  30,000  4,000  50,000  7,000  6,000  6,000  50,000  5,000  10,000  60,000  5,000  50,000  40,000  20,000  25,000  400,000  400,000  60,000  2,500  30,000  12,000  12,000  -    -    60,000  4,000  12...
#  ' 800  170  80  280  55  45  70  160  20  30  20  50  55  23  750  16  12  35  110  30  25  260  18  10  200  340  20  15  115  35  20  15  18  150  300  26  50  12  450  35  12  60  30  18  12  750  8  25  50  22  80  50  35  30  7,500  550,000  30,000  750  1,500  750  650  550  450  850  200  650  550  200  100  750  100  80  550  100  110  90  650  7,500  300  30,000  13,000  15,000  3,500  100  130  7,500  80  1,000  450  330,000  78,000  68,000  15,000  300  750  200  350  275  200  275  5,800  100  1,000  300  200  550  220  130,000  42,000  33,000  1,200  3,300  9,200  9,700  2,300  4,000  6,700  12,800  2,300  32,500  4,300  7,500  27,500  1,500  12,500  750  1,200  5,200  2,500  230  1,000  125  150  1,000  1,000  1,000  50  20  850  200  90  300  65  50  80  175  25  35  23  60  60  26  800  20  15  40  125  35  30  290  20  12  230  370  23  18  130  40  25  18  22  170  340  30  60  15  500  40  15  70  35  22  15  800  10  30  55  25  90  60  40  35  8,000  560,000  32,000  800  1,600  800  700  600  500  900  220  700  600  220  110  800  110  90  600  110  120  100  700  8,000  330  32,000  14,000  16,000  3,800  110  140  8,000  90  1,100  500  145,000  47,000  37,000  1,500  4,000  10,200  10,500  2,700  4,500  7,400  13,600  2,700  34,000  4,600  8,000  29,000  1,600  13,000  800  400,000  82,000  74,000  17,000  320  800  2,200  380  300  220  300  6,200  110  1,100  320  220  600  240  5,800  2,800  1,450  255  1,200  180  200  1,200  1,200  1,200  60...

# %%
#Đếm các giá trị có trong mỗi cột
for col in df.columns:
  print(df[col].value_counts())
# Out:
# Country
# Algeria                  11
# Saudi Arabia             11
# Venezuela                11
# China                    11
# Japan                    11
#                          ..
# Sao Tome and Principe    11
# Rwanda                   11
# Nigeria                  11
# Niger                    11
# Timor-Leste              11
# Name: count, Length: 138, dtype: int64
# Continents
# Africa            594
# America           385
# Europe            220
# Asia              198
# Southeast Asia    121
# Name: count, dtype: int64
# Rate of users\nInternet (%)
# 70.0     33
# 50.0     31
# 80.0     27
# 100.0    27
# 85.0     24
#          ..
# 32.3      1
# 80.1      1
# 30.8      1
# 32.4      1
# 62.5      1
# Name: count, Length: 241, dtype: int64
# Mobile device usage (%)
# 100.0    52
# 80.0     50
# 99.0     49
# 92.0     49
# 85.0     46
#          ..
# 63.9      1
# 94.8      1
# 98.1      1
# 48.5      1
# 98.2      1
# Name: count, Length: 147, dtype: int64
# Revenue of e-commerce platforms (billion USD)
# 0.250      67
# 0.300      60
# 0.200      53
# 0.150      52
# 0.120      50
#            ..
# 25.000      1
# 29.000      1
# 550.000     1
# 0.007       1
# 0.012       1
# Name: count, Length: 243, dtype: int64
# Revenue of IT industry (billion USD)
# 0.100      45
# 0.140      42
# 0.150      42
# 0.130      41
# 0.120      41
#            ..
# 0.660       1
# 21.000      1
# 520.000     1
# 17.000      1
# 0.073       1
# Name: count, Length: 270, dtype: int64
# Funding in digital infrastructure (billion USD)
# 0.00      121
# 0.10       53
# 0.40       39
# 0.15       38
# 0.50       38
#          ...
# 300.00      1
# 3.30        1
# 7.40        1
# 6.20        1
# 7.96        1
# Name: count, Length: 191, dtype: int64
# Foreign investment capital (million USD)
# 0.00      65
# 0.05      26
# 0.25      19
# 0.10      19
# 0.03      18
#           ..
# 25.30      1
# 166.08     1
# 2.69       1
# 1.18       1
# 3.90       1
# Name: count, Length: 746, dtype: int64
# CREDIT and BANKING digital transformation ratio(%)
# 0.0      390
# 15.0      12
# 10.0      11
# 30.0      10
# 50.0      10
#         ...
# 111.1      1
# 100.5      1
# 77.1       1
# 161.8      1
# 98.0       1
# Name: count, Length: 625, dtype: int64
#  Number of Enterprises Applying Digital Transformation (bussiness)
#  20,000      59
#  10,000      58
#  15,000      57
#  -           56
#  12,000      52
#              ..
#  450          1
#  13,500       1
#  12,500       1
#  165,000      1
#  4,800        1
# Name: count, Length: 125, dtype: int64
# Economic Growth Rate of Education (% GDP)
# 4.50    67
# 5.00    63
# 4.00    58
# 4.30    56
# 4.80    54
#         ..
# 2.75     1
# 9.20     1
# 9.30     1
# 9.40     1
# 9.50     1
# Name: count, Length: 74, dtype: int64
#  Number of technology start up businesses
#  50         33
#  60         32
#  55         30
#  35         30
#  45         27
#             ..
#  65,000      1
#  54,000      1
#  6,300       1
#  13,200      1
#  42,500      1
# Name: count, Length: 319, dtype: int64
# Year
# 2014.0    138
# 2015.0    138
# 2016.0    138
# 2017.0    138
# 2018.0    138
# 2019.0    138
# 2020.0    138
# 2021.0    138
# 2022.0    138
# 2023.0    138
# 2024.0    138
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Country                                                                0
# Continents                                                             0
# Rate of users\nInternet (%)                                            0
# Mobile device usage (%)                                                0
# Revenue of e-commerce platforms (billion USD)                          0
# Revenue of IT industry (billion USD)                                   0
# Funding in digital infrastructure (billion USD)                        0
# Foreign investment capital (million USD)                               0
# CREDIT and BANKING digital transformation ratio(%)                     0
#  Number of Enterprises Applying Digital Transformation (bussiness)     0
# Economic Growth Rate of Education (% GDP)                              0
#  Number of technology start up businesses                              0
# Year                                                                   0
# dtype: int64

# %%
# Declare feature vector and target variable
X = df.drop(['Country'], axis = 1)
y = df['Country']

# %%
# split data into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#check
X_train.shape, X_test.shape
# Out:
# ((1017, 12), (501, 12))

# %%
# check data types in X_train

X_train.dtypes
# Out:
# Continents                                                              object
# Rate of users\nInternet (%)                                            float64
# Mobile device usage (%)                                                float64
# Revenue of e-commerce platforms (billion USD)                          float64
# Revenue of IT industry (billion USD)                                   float64
# Funding in digital infrastructure (billion USD)                        float64
# Foreign investment capital (million USD)                               float64
# CREDIT and BANKING digital transformation ratio(%)                     float64
#  Number of Enterprises Applying Digital Transformation (bussiness)      object
# Economic Growth Rate of Education (% GDP)                              float64
#  Number of technology start up businesses                               object
# Year                                                                   float64
# dtype: object

# %%
X_train.head()
# Out:
#      Continents  Rate of users\nInternet (%)  Mobile device usage (%)  \
# 158    Africa                           54.0                     54.0
# 1029    America                         75.0                     88.0
# 1309    America                         62.0                     66.0
# 1258   Africa                            6.0                     48.0
# 352     America                         47.0                     71.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 158                                             0.1
# 1029                                            1.5
# 1309                                            0.7
# 1258                                            0.3
# 352                                            16.0
#
#       Revenue of IT industry (billion USD)  \
# 158                                   0.08
# 1029                                  0.58
# 1309                                  0.58
# 1258                                  0.15
# 352                                  17.00
#
#       Funding in digital infrastructure (billion USD)  \
# 158                                              0.00
# 1029                                             1.10
# 1309                                             0.48
# 1258                                             0.32
# 352                                              8.50
#
#       Foreign investment capital (million USD)  \
# 158                                       0.07
# 1029                                      1.53
# 1309                                      0.50
# 1258                                      0.05
# 352                                      38.29
#
#       CREDIT and BANKING digital transformation ratio(%)  \
# 158                                                 0.0
# 1029                                               78.5
# 1309                                               45.0
# 1258                                                0.0
# 352                                                25.1
#
#       Number of Enterprises Applying Digital Transformation (bussiness)   \
# 158                                              4,000
# 1029                                           160,000
# 1309                                            30,000
# 1258                                            18,000
# 352                                             70,000
#
#       Economic Growth Rate of Education (% GDP)  \
# 158                                         3.9
# 1029                                        4.7
# 1309                                        7.4
# 1258                                        5.9
# 352                                         5.2
#
#       Number of technology start up businesses     Year
# 158                                         30   2015.0
# 1029                                     1,200   2021.0
# 1309                                       380   2023.0
# 1258                                        35   2023.0
# 352                                     34,000   2016.0

# %%
X_test.head()
# Out:
#           Continents  Rate of users\nInternet (%)  Mobile device usage (%)  \
# 231          Europe                          84.0                     71.0
# 1217         Europe                          94.0                     91.0
# 1240  Southeast Asia                         96.5                     92.0
# 1470          Asia                           78.1                     98.2
# 51          Africa                           12.0                     36.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 231                                            4.00
# 1217                                          15.00
# 1240                                           0.12
# 1470                                         102.00
# 51                                             0.25
#
#       Revenue of IT industry (billion USD)  \
# 231                                  6.000
# 1217                                16.000
# 1240                                 0.085
# 1470                               250.000
# 51                                   0.700
#
#       Funding in digital infrastructure (billion USD)  \
# 231                                               3.2
# 1217                                              7.6
# 1240                                              0.1
# 1470                                             32.0
# 51                                                0.0
#
#       Foreign investment capital (million USD)  \
# 231                                      -7.98
# 1217                                     12.48
# 1240                                     -0.29
# 1470                                     55.00
# 51                                        1.06
#
#       CREDIT and BANKING digital transformation ratio(%)  \
# 231                                                85.4
# 1217                                               71.8
# 1240                                               40.0
# 1470                                                0.0
# 51                                                  0.0
#
#       Number of Enterprises Applying Digital Transformation (bussiness)   \
# 231                                             30,000
# 1217                                           100,000
# 1240                                            20,000
# 1470                                           160,000
# 51                                              30,000
#
#       Economic Growth Rate of Education (% GDP)  \
# 231                                         6.4
# 1217                                        6.9
# 1240                                        2.9
# 1470                                        5.0
# 51                                          4.5
#
#       Number of technology start up businesses     Year
# 231                                      4,000   2015.0
# 1217                                    17,000   2022.0
# 1240                                       220   2022.0
# 1470                                   130,000   2024.0
# 51                                          50   2014.0

# %%
# Sử dụng One-Hot Encoding cho cột 'Continents'
X_train = pd.get_dummies(X_train, columns=['Continents'])

X_test = pd.get_dummies(X_test, columns=['Continents'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-2b6f141e4615> in <cell line: 2>()
#       1 # Sử dụng One-Hot Encoding cho cột 'Continents'
# ----> 2 X_train = pd.get_dummies(X_train, columns=['Continents'])
#       3
#       4 X_test = pd.get_dummies(X_test, columns=['Continents'])
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     162             raise TypeError("Input must be a list-like for parameter `columns`")
#     163         else:
# --> 164             data_to_encode = data[columns]
#     165
#     166         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3897             if is_iterator(key):
#    3898                 key = list(key)
# -> 3899             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3900
#    3901         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6113             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6114
# -> 6115         self._raise_if_missing(keyarr, indexer, axis_name)
#    6116
#    6117         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6174                 if use_interval_msg:
#    6175                     key = list(key)
# -> 6176                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177
#    6178             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Continents'], dtype='object')] are in the [columns]"

# %%
X_test.head()
# Out:
#       Rate of users\nInternet (%)  Mobile device usage (%)  \
# 231                          84.0                     71.0
# 1217                         94.0                     91.0
# 1240                         96.5                     92.0
# 1470                         78.1                     98.2
# 51                           12.0                     36.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 231                                            4.00
# 1217                                          15.00
# 1240                                           0.12
# 1470                                         102.00
# 51                                             0.25
#
#       Revenue of IT industry (billion USD)  \
# 231                                  6.000
# 1217                                16.000
# 1240                                 0.085
# 1470                               250.000
# 51                                   0.700
#
#       Funding in digital infrastructure (billion USD)  \
# 231                                               3.2
# 1217                                              7.6
# 1240                                              0.1
# 1470                                             32.0
# 51                                                0.0
#
#       Foreign investment capital (million USD)  \
# 231                                      -7.98
# 1217                                     12.48
# 1240                                     -0.29
# 1470                                     55.00
# 51                                        1.06
#
#       CREDIT and BANKING digital transformation ratio(%)  \
# 231                                                85.4
# 1217                                               71.8
# 1240                                               40.0
# 1470                                                0.0
# 51                                                  0.0
#
#       Number of Enterprises Applying Digital Transformation (bussiness)   \
# 231                                             30,000
# 1217                                           100,000
# 1240                                            20,000
# 1470                                           160,000
# 51                                              30,000
#
#       Economic Growth Rate of Education (% GDP)  \
# 231                                         6.4
# 1217                                        6.9
# 1240                                        2.9
# 1470                                        5.0
# 51                                          4.5
#
#       Number of technology start up businesses     Year  Continents_Africa    \
# 231                                      4,000   2015.0                False
# 1217                                    17,000   2022.0                False
# 1240                                       220   2022.0                False
# 1470                                   130,000   2024.0                False
# 51                                          50   2014.0                 True
#
#       Continents_America  Continents_Asia    Continents_Europe   \
# 231                False              False                True
# 1217               False              False                True
# 1240               False              False               False
# 1470               False               True               False
# 51                 False              False               False
#
#       Continents_Southeast Asia
# 231                       False
# 1217                      False
# 1240                       True
# 1470                      False
# 51                        False

# %%
# import Random Forest classifier

from sklearn.ensemble import RandomForestClassifier

# instantiate the classifier

rfc = RandomForestClassifier(random_state=0)

# fit the model

rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# Check accuracy score

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-0e776fa9715f> in <cell line: 11>()
#       9 # fit the model
#      10
# ---> 11 rfc.fit(X_train, y_train)
#      12
#      13 # Predict the Test set results
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     361             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     362
# --> 363         X, y = self._validate_data(
#     364             X,
#     365             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1299         )
#    1300
# -> 1301     X = check_array(
#    1302         X,
#    1303         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     927         # Use the original dtype for conversion if dtype is None
#     928         new_dtype = dtype_orig if dtype is None else dtype
# --> 929         array = array.astype(new_dtype)
#     930         # Since we converted here, we do not need to convert again later
#     931         dtype = None
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6532         else:
#    6533             # else, only a single dtype is given
# -> 6534             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412             copy = False
#     413
# --> 414         return self.apply(
#     415             "astype",
#     416             dtype=dtype,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     352                 applied = b.apply(f, **kwargs)
#     353             else:
# --> 354                 applied = getattr(b, f)(**kwargs)
#     355             result_blocks = extend_blocks(applied, result_blocks)
#     356
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow)
#     614         values = self.values
#     615
# --> 616         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     617
#     618         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     236
#     237     try:
# --> 238         new_values = astype_array(values, dtype, copy=copy)
#     239     except (ValueError, TypeError):
#     240         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     181
#     182     else:
# --> 183         values = _astype_nansafe(values, dtype, copy=copy)
#     184
#     185     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     132     if copy or arr.dtype == object or dtype == object:
#     133         # Explicit copy, or required since NumPy can't view from / to object.
# --> 134         return arr.astype(dtype, copy=True)
#     135
#     136     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: ' 4,000 '

# %%
# Loại bỏ khoảng trắng, thay dấy , -> .
X_train = X_train.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
X_test = X_test.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Chuyển string -> float
X_train = X_train.apply(lambda x: x.str.replace(',', '').astype(float) if x.dtype == "object" else x)
X_test = X_test.apply(lambda x: x.str.replace(',', '').astype(float) if x.dtype == "object" else x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-27eeaead71e3> in <cell line: 6>()
#       4
#       5 # Chuyển string -> float
# ----> 6 X_train = X_train.apply(lambda x: x.str.replace(',', '').astype(float) if x.dtype == "object" else x)
#       7 X_test = X_test.apply(lambda x: x.str.replace(',', '').astype(float) if x.dtype == "object" else x)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10032             kwargs=kwargs,
#   10033         )
# > 10034         return op.apply().__finalize__(self, method="apply")
#   10035
#   10036     def map(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     835             return self.apply_raw()
#     836
# --> 837         return self.apply_standard()
#     838
#     839     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     963
#     964     def apply_standard(self):
# --> 965         results, res_index = self.apply_series_generator()
#     966
#     967         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     979             for i, v in enumerate(series_gen):
#     980                 # ignore SettingWithCopy here in case the user mutates
# --> 981                 results[i] = self.func(v, *self.args, **self.kwargs)
#     982                 if isinstance(results[i], ABCSeries):
#     983                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-47-27eeaead71e3> in <lambda>(x)
#       4
#       5 # Chuyển string -> float
# ----> 6 X_train = X_train.apply(lambda x: x.str.replace(',', '').astype(float) if x.dtype == "object" else x)
#       7 X_test = X_test.apply(lambda x: x.str.replace(',', '').astype(float) if x.dtype == "object" else x)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6532         else:
#    6533             # else, only a single dtype is given
# -> 6534             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412             copy = False
#     413
# --> 414         return self.apply(
#     415             "astype",
#     416             dtype=dtype,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     352                 applied = b.apply(f, **kwargs)
#     353             else:
# --> 354                 applied = getattr(b, f)(**kwargs)
#     355             result_blocks = extend_blocks(applied, result_blocks)
#     356
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow)
#     614         values = self.values
#     615
# --> 616         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     617
#     618         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     236
#     237     try:
# --> 238         new_values = astype_array(values, dtype, copy=copy)
#     239     except (ValueError, TypeError):
#     240         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     181
#     182     else:
# --> 183         values = _astype_nansafe(values, dtype, copy=copy)
#     184
#     185     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     132     if copy or arr.dtype == object or dtype == object:
#     133         # Explicit copy, or required since NumPy can't view from / to object.
# --> 134         return arr.astype(dtype, copy=True)
#     135
#     136     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
X_train.head(10)
# Out:
#       Rate of users\nInternet (%)  Mobile device usage (%)  \
# 158                          54.0                     54.0
# 1029                         75.0                     88.0
# 1309                         62.0                     66.0
# 1258                          6.0                     48.0
# 352                          47.0                     71.0
# 756                          91.0                     94.0
# 1312                         86.0                     92.0
# 605                          40.0                     67.0
# 596                           8.0                     50.0
# 602                          57.0                     75.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 158                                            0.10
# 1029                                           1.50
# 1309                                           0.70
# 1258                                           0.30
# 352                                           16.00
# 756                                            0.20
# 1312                                           0.25
# 605                                            0.90
# 596                                            0.18
# 602                                            1.60
#
#       Revenue of IT industry (billion USD)  \
# 158                                   0.08
# 1029                                  0.58
# 1309                                  0.58
# 1258                                  0.15
# 352                                  17.00
# 756                                   0.42
# 1312                                  0.19
# 605                                   1.00
# 596                                   0.10
# 602                                   1.40
#
#       Funding in digital infrastructure (billion USD)  \
# 158                                              0.00
# 1029                                             1.10
# 1309                                             0.48
# 1258                                             0.32
# 352                                              8.50
# 756                                              0.42
# 1312                                             0.20
# 605                                              0.07
# 596                                              0.02
# 602                                              0.30
#
#       Foreign investment capital (million USD)  \
# 158                                      0.070
# 1029                                     1.530
# 1309                                     0.500
# 1258                                     0.050
# 352                                     38.290
# 756                                      0.215
# 1312                                     0.160
# 605                                      0.720
# 596                                      0.410
# 602                                      0.990
#
#       CREDIT and BANKING digital transformation ratio(%)  \
# 158                                                 0.0
# 1029                                               78.5
# 1309                                               45.0
# 1258                                                0.0
# 352                                                25.1
# 756                                                77.2
# 1312                                               51.6
# 605                                                 5.8
# 596                                                 0.0
# 602                                                63.5
#
#       Number of Enterprises Applying Digital Transformation (bussiness)   \
# 158                                               4,000
# 1029                                            160,000
# 1309                                             30,000
# 1258                                             18,000
# 352                                              70,000
# 756                                              60,000
# 1312                                                  -
# 605                                              50,000
# 596                                              12,000
# 602                                              80,000
#
#       Economic Growth Rate of Education (% GDP)  \
# 158                                         3.9
# 1029                                        4.7
# 1309                                        7.4
# 1258                                        5.9
# 352                                         5.2
# 756                                         4.0
# 1312                                        5.4
# 605                                         3.8
# 596                                         3.4
# 602                                         6.9
#
#       Number of technology start up businesses     Year  Continents_Africa    \
# 158                                          30  2015.0                 True
# 1029                                      1,200  2021.0                False
# 1309                                        380  2023.0                False
# 1258                                         35  2023.0                 True
# 352                                      34,000  2016.0                False
# 756                                         800  2019.0                False
# 1312                                        190  2023.0                False
# 605                                          50  2018.0                 True
# 596                                          26  2018.0                 True
# 602                                         120  2018.0                 True
#
#       Continents_America  Continents_Asia    Continents_Europe   \
# 158                False              False               False
# 1029                True              False               False
# 1309                True              False               False
# 1258               False              False               False
# 352                 True              False               False
# 756                 True              False               False
# 1312                True              False               False
# 605                False              False               False
# 596                False              False               False
# 602                False              False               False
#
#       Continents_Southeast Asia
# 158                       False
# 1029                      False
# 1309                      False
# 1258                      False
# 352                       False
# 756                       False
# 1312                      False
# 605                       False
# 596                       False
# 602                       False

# %%
# Loại bỏ khoảng trắng đầu cuối
X_train = X_train.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
X_test = X_test.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Thay dấu phẩy, chuyển thành float, và thay giá trị không hợp lệ bằng 0
X_train = X_train.apply(lambda x: pd.to_numeric(x.str.replace(',', ''), errors='coerce').fillna(0) if x.dtype == "object" else x)
X_test = X_test.apply(lambda x: pd.to_numeric(x.str.replace(',', ''), errors='coerce').fillna(0) if x.dtype == "object" else x)

# %%
X_train.head(10)
# Out:
#       Rate of users\nInternet (%)  Mobile device usage (%)  \
# 158                          54.0                     54.0
# 1029                         75.0                     88.0
# 1309                         62.0                     66.0
# 1258                          6.0                     48.0
# 352                          47.0                     71.0
# 756                          91.0                     94.0
# 1312                         86.0                     92.0
# 605                          40.0                     67.0
# 596                           8.0                     50.0
# 602                          57.0                     75.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 158                                            0.10
# 1029                                           1.50
# 1309                                           0.70
# 1258                                           0.30
# 352                                           16.00
# 756                                            0.20
# 1312                                           0.25
# 605                                            0.90
# 596                                            0.18
# 602                                            1.60
#
#       Revenue of IT industry (billion USD)  \
# 158                                   0.08
# 1029                                  0.58
# 1309                                  0.58
# 1258                                  0.15
# 352                                  17.00
# 756                                   0.42
# 1312                                  0.19
# 605                                   1.00
# 596                                   0.10
# 602                                   1.40
#
#       Funding in digital infrastructure (billion USD)  \
# 158                                              0.00
# 1029                                             1.10
# 1309                                             0.48
# 1258                                             0.32
# 352                                              8.50
# 756                                              0.42
# 1312                                             0.20
# 605                                              0.07
# 596                                              0.02
# 602                                              0.30
#
#       Foreign investment capital (million USD)  \
# 158                                      0.070
# 1029                                     1.530
# 1309                                     0.500
# 1258                                     0.050
# 352                                     38.290
# 756                                      0.215
# 1312                                     0.160
# 605                                      0.720
# 596                                      0.410
# 602                                      0.990
#
#       CREDIT and BANKING digital transformation ratio(%)  \
# 158                                                 0.0
# 1029                                               78.5
# 1309                                               45.0
# 1258                                                0.0
# 352                                                25.1
# 756                                                77.2
# 1312                                               51.6
# 605                                                 5.8
# 596                                                 0.0
# 602                                                63.5
#
#        Number of Enterprises Applying Digital Transformation (bussiness)   \
# 158                                              4000.0
# 1029                                           160000.0
# 1309                                            30000.0
# 1258                                            18000.0
# 352                                             70000.0
# 756                                             60000.0
# 1312                                                0.0
# 605                                             50000.0
# 596                                             12000.0
# 602                                             80000.0
#
#       Economic Growth Rate of Education (% GDP)  \
# 158                                         3.9
# 1029                                        4.7
# 1309                                        7.4
# 1258                                        5.9
# 352                                         5.2
# 756                                         4.0
# 1312                                        5.4
# 605                                         3.8
# 596                                         3.4
# 602                                         6.9
#
#        Number of technology start up businesses     Year  Continents_Africa    \
# 158                                           30  2015.0                 True
# 1029                                        1200  2021.0                False
# 1309                                         380  2023.0                False
# 1258                                          35  2023.0                 True
# 352                                        34000  2016.0                False
# 756                                          800  2019.0                False
# 1312                                         190  2023.0                False
# 605                                           50  2018.0                 True
# 596                                           26  2018.0                 True
# 602                                          120  2018.0                 True
#
#       Continents_America  Continents_Asia    Continents_Europe   \
# 158                False              False               False
# 1029                True              False               False
# 1309                True              False               False
# 1258               False              False               False
# 352                 True              False               False
# 756                 True              False               False
# 1312                True              False               False
# 605                False              False               False
# 596                False              False               False
# 602                False              False               False
#
#       Continents_Southeast Asia
# 158                       False
# 1029                      False
# 1309                      False
# 1258                      False
# 352                       False
# 756                       False
# 1312                      False
# 605                       False
# 596                       False
# 602                       False

# %%
# import Random Forest classifier

from sklearn.ensemble import RandomForestClassifier

# instantiate the classifier

rfc = RandomForestClassifier(random_state=0)

# fit the model

rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# Check accuracy score

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.8802

# %%
# instantiate the classifier with n_estimators = 100

rfc_100 = RandomForestClassifier(n_estimators=100, random_state=0)

# fit the model to the training set

rfc_100.fit(X_train, y_train)

# Predict on the test set results

y_pred_100 = rfc_100.predict(X_test)

# Check accuracy score

print('Model accuracy score with 100 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred_100)))
# Out:
# Model accuracy score with 100 decision-trees : 0.8802

# %% [markdown]
# Độ chính xác của mô hình với 10 cây quyết định là 0.8802 bằng với 100 cây quyết định -> Có tính ổn định

# %%
# create the classifier with n_estimators = 100

clf = RandomForestClassifier(n_estimators=100, random_state=0)

# fit the model to the training set

clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# view the feature scores

feature_scores = pd.Series(clf.feature_importances_, index=X_train.columns).sort_values(ascending=False)

feature_scores
# Out:
#  Number of technology start up businesses                              0.118936
# Revenue of IT industry (billion USD)                                   0.118431
# Economic Growth Rate of Education (% GDP)                              0.113227
# Foreign investment capital (million USD)                               0.096447
# Revenue of e-commerce platforms (billion USD)                          0.092543
# CREDIT and BANKING digital transformation ratio(%)                     0.090106
# Funding in digital infrastructure (billion USD)                        0.089365
# Rate of users\nInternet (%)                                            0.079539
#  Number of Enterprises Applying Digital Transformation (bussiness)     0.065226
# Mobile device usage (%)                                                0.064128
# Year                                                                   0.022640
# Continents_America                                                     0.011292
# Continents_Europe                                                      0.010121
# Continents_Asia                                                        0.009723
# Continents_Southeast Asia                                              0.009336
# Continents_Africa                                                      0.008939
# dtype: float64

# %%
# Creating a seaborn bar plot

sns.barplot(x=feature_scores, y=feature_scores.index)

# Add labels to the graph

plt.xlabel('Feature Importance Score')

plt.ylabel('Features')

# Add title to the graph

plt.title("Visualizing Important Features")


# Visualize the graph

plt.show()
